# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Out:
#   Cell In[2], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
data1 = pd.read_csv(r'C:\Users\Acer\Desktop\AWD\GLDAS_7_POINTS\.csv')
data2 = pd.read_csv(r'C:\Users\Acer\Desktop\AWD\GLDAS_7_POINTS\.csv')
data3 = pd.read_csv(r'C:\Users\Acer\Desktop\AWD\GLDAS_7_POINTS\.csv')
data4 = pd.read_csv(r'C:\Users\Acer\Desktop\AWD\GLDAS_7_POINTS\.csv')
data5 = pd.read_csv(r'C:\Users\Acer\Desktop\AWD\GLDAS_7_POINTS\.csv')
data6 = pd.read_csv(r'C:\Users\Acer\Desktop\AWD\GLDAS_7_POINTS\.csv')
data7 = pd.read_csv(r'C:\Users\Acer\Desktop\AWD\GLDAS_7_POINTS\.csv')

# %%
my_data1 = pd.read_csv(data1)
my_data2 = pd.read_csv(data2)
my_data3 = pd.read_csv(data3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 my_data1 = pd.read_csv(data1)
#       2 my_data2 = pd.read_csv(data2)
#       3 my_data3 = pd.read_csv(data3)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
data1
data2
data3
# Out:
#          system:index        date  soil_moisture  \
# 0      A20000101_0300  2000-01-01      20.673000
# 1      A20000101_0600  2000-01-01      20.606001
# 2      A20000101_0900  2000-01-01      20.518999
# 3      A20000101_1200  2000-01-01      20.506001
# 4      A20000101_1500  2000-01-01      20.525000
# ...               ...         ...            ...
# 64274  A20211230_0900  2021-12-30      24.503000
# 64275  A20211230_1200  2021-12-30      24.416000
# 64276  A20211230_1500  2021-12-30      24.400000
# 64277  A20211230_1800  2021-12-30      24.386000
# 64278  A20211230_2100  2021-12-30      24.378000
#
#                                                     .geo
# 0      {"type":"Point","coordinates":[81.045105,29.34...
# 1      {"type":"Point","coordinates":[81.045105,29.34...
# 2      {"type":"Point","coordinates":[81.045105,29.34...
# 3      {"type":"Point","coordinates":[81.045105,29.34...
# 4      {"type":"Point","coordinates":[81.045105,29.34...
# ...

# %%
data1['soil_moisture']=data1['soil_moisture']/100
data2['soil_moisture']=data2['soil_moisture']/100
data3['soil_moisture']=data3['soil_moisture']/100
data4['soil_moisture']=data4['soil_moisture']/100
data5['soil_moisture']=data5['soil_moisture']/100
data6['soil_moisture']=data6['soil_moisture']/100
data7['soil_moisture']=data7['soil_moisture']/100

# %%
data1
# Out:
#          system:index        date  soil_moisture  \
# 0      A20000101_0300  2000-01-01        0.17768
# 1      A20000101_0600  2000-01-01        0.17691
# 2      A20000101_0900  2000-01-01        0.17592
# 3      A20000101_1200  2000-01-01        0.17567
# 4      A20000101_1500  2000-01-01        0.17582
# ...               ...         ...            ...
# 64274  A20211230_0900  2021-12-30        0.24162
# 64275  A20211230_1200  2021-12-30        0.24086
# 64276  A20211230_1500  2021-12-30        0.24053
# 64277  A20211230_1800  2021-12-30        0.24033
# 64278  A20211230_2100  2021-12-30        0.24037
#
#                                                     .geo
# 0      {"type":"Point","coordinates":[81.62608333,28....
# 1      {"type":"Point","coordinates":[81.62608333,28....
# 2      {"type":"Point","coordinates":[81.62608333,28....
# 3      {"type":"Point","coordinates":[81.62608333,28....
# 4      {"type":"Point","coordinates":[81.62608333,28....
# ...

# %%
data1['date']
data2['date']
data3['date']
# Out:
# 0        2000-01-01
# 1        2000-01-01
# 2        2000-01-01
# 3        2000-01-01
# 4        2000-01-01
#             ...
# 64274    2021-12-30
# 64275    2021-12-30
# 64276    2021-12-30
# 64277    2021-12-30
# 64278    2021-12-30
# Name: date, Length: 64279, dtype: object

# %%
print("Before conversion:")
print(my_data1['Date'].head())

try:
    my_data1['Date'] = pd.to_datetime(my_data1['Date'])
    print("Conversion successful.")
except Exception as e:
    print(f"Error during conversion: {e}")

print("After conversion:")
print(my_data1['Date'].head())
# Out:
# Before conversion:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 2
#       1 print("Before conversion:")
# ----> 2 print(my_data1['Date'].head())
#       4 try:
#       5     my_data1['Date'] = pd.to_datetime(my_data1['Date'])
#
# NameError: name 'my_data1' is not defined

# %%
print("Before conversion:")
print(my_data2['Date'].head())

try:
    my_data2['Date'] = pd.to_datetime(my_data2['Date'])
    print("Conversion successful.")
except Exception as e:
    print(f"Error during conversion: {e}")

print("After conversion:")
print(my_data2['Date'].head())
# Out:
# Before conversion:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 2
#       1 print("Before conversion:")
# ----> 2 print(my_data2['Date'].head())
#       4 try:
#       5     my_data2['Date'] = pd.to_datetime(my_data2['Date'])
#
# NameError: name 'my_data2' is not defined

# %%
print("Before conversion:")
print(my_data3['Date'].head())

try:
    my_data3['Date'] = pd.to_datetime(my_data3['Date'])
    print("Conversion successful.")
except Exception as e:
    print(f"Error during conversion: {e}")

print("After conversion:")
print(my_data3['Date'].head())
# Out:
# Before conversion:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 print("Before conversion:")
# ----> 2 print(my_data3['Date'].head())
#       4 try:
#       5     my_data3['Date'] = pd.to_datetime(my_data3['Date'])
#
# NameError: name 'my_data3' is not defined

# %%
try:
    my_data3['Date'] = pd.to_datetime(my_data3['Date'], format='%Y-%m-%d')  # Adjust the format as needed
    print("Conversion successful.")
except Exception as e:
    print(f"Error during conversion: {e}")
# Out:
# Error during conversion: 'Date'

# %%
try:
    my_data3['Date'] = pd.to_datetime(my_data3['Date'])
    print("Conversion successful.")
except pd.errors.OutOfBoundsDatetime as e:
    print(f"Error: Out of bounds datetime encountered in my_data3['Date']")
except Exception as e:
    print(f"Error during conversion: {e}")
# Out:
# Error during conversion: 'Date'

# %%
data1['date'] = pd.to_datetime(data1['date'])
data2['date'] = pd.to_datetime(data2['date'])
data3['date'] = pd.to_datetime(data3['date'])
data4['date'] = pd.to_datetime(data4['date'])
data5['date'] = pd.to_datetime(data5['date'])
data6['date'] = pd.to_datetime(data6['date'])
data7['date'] = pd.to_datetime(data7['date'])

# %%
data1
data2
# Out:
#          date  Average of SM       SWDI  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  2015-04-01       0.213482  -6.161885         NaN         NaN         NaN
# 1  2015-05-01       0.165499  -7.388841         NaN         NaN         NaN
# 2  2015-06-01       0.130270  -8.289672         NaN         NaN         NaN
# 3  2015-07-01       0.451292  -0.080967         NaN         NaN         NaN
# 4  2015-08-01       0.450748  -0.094870         NaN         NaN         NaN
# ..        ...            ...        ...         ...         ...         ...
# 64 2020-08-01       0.293110  -4.125760         NaN         NaN         NaN
# 65 2020-09-01       0.265859  -4.822574         NaN         NaN         NaN
# 66 2020-10-01       0.113178  -8.726725         NaN         NaN         NaN
# 67 2020-11-01       0.061261 -10.054270         NaN         NaN         NaN
# 68 2020-12-01       0.037795 -10.654309         NaN         NaN         NaN
#
#     Unnamed: 6
# 0          NaN
# 1          NaN
# ...

# %%
new_data1 = data1
new_data2 = data2
new_data3 = data3
new_data4 = data4
new_data5 = data5
new_data6 = data6
new_data7 = data7

# %%
new_data1
new_data2
new_data3
# Out:
#          system:index       date  soil_moisture  \
# 0      A20000101_0300 2000-01-01        0.20673
# 1      A20000101_0600 2000-01-01        0.20606
# 2      A20000101_0900 2000-01-01        0.20519
# 3      A20000101_1200 2000-01-01        0.20506
# 4      A20000101_1500 2000-01-01        0.20525
# ...               ...        ...            ...
# 64274  A20211230_0900 2021-12-30        0.24503
# 64275  A20211230_1200 2021-12-30        0.24416
# 64276  A20211230_1500 2021-12-30        0.24400
# 64277  A20211230_1800 2021-12-30        0.24386
# 64278  A20211230_2100 2021-12-30        0.24378
#
#                                                     .geo
# 0      {"type":"Point","coordinates":[81.045105,29.34...
# 1      {"type":"Point","coordinates":[81.045105,29.34...
# 2      {"type":"Point","coordinates":[81.045105,29.34...
# 3      {"type":"Point","coordinates":[81.045105,29.34...
# 4      {"type":"Point","coordinates":[81.045105,29.34...
# ...

# %%
plt.figure(figsize = (30,10))
plt.plot(new_data1['date'], new_data1['SWDI'], color='tab:blue', linewidth=2 , label ='Jhingrana')
#plt.legend(["SM for terai", "SM for hilly", "SM for himalayan"])
plt.plot(new_data2['date'], new_data2['SWDI'], color='tab:orange', linewidth=2 , label = 'Dadimadi')
plt.plot(new_data3['date'], new_data3['SWDI'], color='tab:green', linewidth=2 , label= 'Jagatipur')
plt.plot(new_data4['date'], new_data4['SWDI'], color='tab:red', linewidth=2 , label ='Rulbang(Juwang)')
plt.plot(new_data5['date'], new_data5['SWDI'], color='tab:purple', linewidth=2 , label ='Musikot')
plt.plot(new_data6['date'], new_data6['SWDI'], color='tab:brown', linewidth=2 , label ='Ramjakot')
plt.plot(new_data7['date'], new_data7['SWDI'], color='tab:pink', linewidth=2 , label ='Markhu Gaun')
plt.plot(new_data8['date'], new_data8['SWDI'], color='tab:gray', linewidth=2 , label ='Panchkhal')
plt.plot(new_data9['date'], new_data9['SWDI'], color='tab:olive', linewidth=2 , label =' Aisealukhark')
plt.plot(new_data10['date'], new_data10['SWDI'], color='tab:cyan', linewidth=2 , label ='Phidim(Panchthar)')
plt.legend()
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('SWDI in mm')
plt.title('Time series plot for SWDI in different parts of Hilly Region')
plt.tight_layout()
plt.show()

# %%
export_data1 = new_data1.describe()
export_data2 = new_data2.describe()
export_data3 = new_data3.describe()
export_data4 = new_data4.describe()
export_data5 = new_data5.describe()
export_data6 = new_data6.describe()
export_data7 = new_data7.describe()
export_data8 = new_data8.describe()
export_data9 = new_data9.describe()
export_data10 = new_data10.describe()

# %%
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')
export_data2.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryhilly.csv')
export_data3.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryhimalayan.csv')
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')
export_data1.to_csv(r'C:\Users\Acer\Desktop\GLDAS\summaryterai.csv')

# %%
# Assuming new_dataX['SM'] are the correct keys for your soil moisture data
# and they all are pandas Series or lists.
data_to_plot = [
    new_data1['Average of SM'],
    new_data2['Average of SM'],
    new_data3['Average of SM'],
    new_data4['Average of SM'],
    new_data5['Average of SM'],
    new_data6['Average of SM'],
    new_data7['Average of SM'],
    new_data8['Average of SM'],
    new_data9['Average of SM'],
    new_data10['Average of SM']
]

plt.boxplot(data_to_plot)
plt.title('Box plot for Soil Moisture in Different Regions of Hilly Region')
plt.xlabel('Region')
plt.ylabel('soil moiture(SM)')

# This will add labels to the x-axis for each boxplot corresponding to each dataset.
region_names = ['Jhingrana', 'Dadimadi', 'Jagatipur', ' Rulbang(Juwang)', 'Musikot', 'Ramjakot', 'Markhu Gaun', 'Panchkhal', 'Aisealukhark','Phidim(Panchthar)']
plt.xticks(range(1, len(region_names) + 1), region_names, rotation=45)  # Adjust as necessary

plt.show()

# %%
def swdijhingrana(SM):
    return 10*(SM-  0.32164)/(0.32384- 0.09542)
export1 = new_data7['soil_moisture'].apply(swdijhingrana)

# %%
export1.to_csv(r'C:\Users\Acer\Desktop\AWD\GLDAS_7_POINTS\Tinje.csv')

# %%
new_data1.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\1751718735.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data1.quantile(.05)
# soil_moisture    0.10923
# Name: 0.05, dtype: float64

# %%
new_data1.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\1980299720.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data1.quantile(.95)
# soil_moisture    0.330311
# Name: 0.95, dtype: float64

# %%
new_data2.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\1745454237.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data2.quantile(.95)
# soil_moisture    0.324681
# Name: 0.95, dtype: float64

# %%
new_data2.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\2598730245.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data2.quantile(.05)
# soil_moisture    0.10835
# Name: 0.05, dtype: float64

# %%
new_data3.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\1508101085.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data3.quantile(.05)
# soil_moisture    0.131069
# Name: 0.05, dtype: float64

# %%
new_data3.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\1784730705.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data3.quantile(.95)
# soil_moisture    0.318071
# Name: 0.95, dtype: float64

# %%
new_data4.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\4234787894.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data4.quantile(.95)
# soil_moisture    0.32458
# Name: 0.95, dtype: float64

# %%
new_data4.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\3429231569.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data4.quantile(.05)
# soil_moisture    0.14441
# Name: 0.05, dtype: float64

# %%
new_data5.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\2599366316.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data5.quantile(.95)
# soil_moisture    0.305101
# Name: 0.95, dtype: float64

# %%
new_data5.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\1412183206.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data5.quantile(.05)
# soil_moisture    0.102869
# Name: 0.05, dtype: float64

# %%
new_data6.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\2304355895.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data6.quantile(.95)
# soil_moisture    0.32384
# Name: 0.95, dtype: float64

# %%
new_data6.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\1245163144.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data6.quantile(.05)
# soil_moisture    0.10695
# Name: 0.05, dtype: float64

# %%
new_data7.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\3381477737.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data7.quantile(.95)
# soil_moisture    0.32164
# Name: 0.95, dtype: float64

# %%
new_data7.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8848\3386674001.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data7.quantile(.05)
# soil_moisture    0.09542
# Name: 0.05, dtype: float64

# %%
new_data8.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14052\3269311695.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data8.quantile(.95)
# month    12.0000
# SM        0.4263
# Name: 0.95, dtype: float64

# %%
new_data8.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14052\3451842951.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data8.quantile(.05)
# month    1.000000
# SM       0.109331
# Name: 0.05, dtype: float64

# %%
new_data9.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14052\747316600.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data9.quantile(.95)
# month    12.000000
# SM        0.424545
# Name: 0.95, dtype: float64

# %%
new_data9.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14052\1276336281.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data9.quantile(.05)
# month    1.000000
# SM       0.177574
# Name: 0.05, dtype: float64

# %%
new_data10.quantile(.95)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14052\1269351583.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data10.quantile(.95)
# month    12.000000
# SM        0.419287
# Name: 0.95, dtype: float64

# %%
new_data10.quantile(.05)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_14052\4165082726.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data10.quantile(.05)
# month    1.000000
# SM       0.126476
# Name: 0.05, dtype: float64

# %%
def swdidadimadi(SM):
    return 10*(SM-  0.4031)/(  0.4031- 0.1207)
export2 = new_data2['SM'].apply(swdidadimadi)

# %%
export2.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Dadimadi.csv')

# %%
def swdijagatipur(SM):
    return 10*(SM- 0.4081)/( 0.4081-0.10177)
export3 = new_data3['SM'].apply(swdijagatipur)

# %%
export3.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Jagatipur.csv')

# %%
def swdiRULBANG(SM):
    return 10*(SM- 0.4271)/(0.4271- 0.1264)
export4 = new_data4['SM'].apply(swdiRULBANG)

# %%
export4.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Rulbang Juwang.csv')

# %%
def swdimusikot(SM):
    return 10*(SM-0.5057)/(0.5057- 0.0386)
export5 = new_data5['SM'].apply(swdimusikot)

# %%
export5.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Musikot.csv')

# %%
def swdiramjakot(SM):
    return 10*(SM- 0.4006)/(0.4006- 0.1384)
export6 = new_data6['SM'].apply(swdiramjakot)

# %%
export6.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Ramjakot.csv')

# %%
def swdimarkhu(SM):
    return 10*(SM- 0.4441)/(0.4441- 0.1566)
export7 = new_data7['SM'].apply(swdimarkhu)

# %%
export7.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Markhu Gaun.csv')

# %%
def swdipanchkhal(SM):
    return 10*(SM- 0.4263)/( 0.4263- 0.1093)
export8 = new_data8['SM'].apply(swdipanchkhal)

# %%
export8.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Panchkhal1.csv')

# %%
def swdishreemastha(SM):
    return 10*(SM- 0.4245)/(0.4245- 0.1775)
export9 = new_data9['SM'].apply(swdishreemastha)

# %%
export9.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Aisealu Khark.csv')

# %%
def swditinje(SM):
    return 10*(SM-0.4192)/(0.4192- 0.1264)
export10 = new_data10['SM'].apply(swditinje)

# %%
export10.to_csv(r'C:\Users\Acer\Desktop\shishir\HILLY\swdi\Phidim Panchthar.csv')

# %%
plt.boxplot(new_data2['SM'])
plt.title('Box plot for hilly')
# Out:
# Text(0.5, 1.0, 'Box plot for hilly')

# %%
plt.boxplot(new_data3['SM'])
plt.title('Box plot for himalayan')
# Out:
# Text(0.5, 1.0, 'Box plot for himalayan')
